# %% [markdown]
# # Load Data

# %%
from src.data_loader import load_data
from src.features import generate_feature
from src.models import modeling
from src.pricing.optimizer import optimize_price_plan
import matplotlib.pyplot as plt
import datetime
import numpy as np
from sklearn.linear_model import LinearRegression
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       2 from src.features import generate_feature
#       3 from src.models import modeling
# ----> 4 from src.pricing.optimizer import optimize_price_plan
#       5 import matplotlib.pyplot as plt
#       6 import datetime
#
# File ~\Documents\Projects\simcel\submission\src\pricing\optimizer.py:23
#      20 import yaml
#      22 # --- import your feature function ---
# ---> 23 from features import generate_feature
#      25 # ------------------ Paths ------------------
#      26 _THIS_DIR = os.path.dirname(os.path.abspath(__file__))
#
# ModuleNotFoundError: No module named 'features'

# %%
df0 = load_data('ai-ml-challenge-main/retail_pricing_demand_2024.csv')
df0 = generate_feature(df0)

# %%
df0[df0.date==datetime.datetime(2024,9,30)][['date', 'store_id', 'sku_id', 'base_price', 'promo_flag', 'promo_depth',
       'final_price', 'competitor_price', 'holiday_flag', 'weather_index',
       'week_of_year', 'units_sold', 'revenue', 'margin', 'stock_cap', 'stockout_flag', 'set']].drop_duplicates()
# Out:
#            date store_id  sku_id  base_price  promo_flag  promo_depth  \
# 4155 2024-09-30      S01  SKU001       10.49           0         0.00
# 4157 2024-09-30      S01  SKU002       15.49           0         0.00
# 4159 2024-09-30      S01  SKU003       21.99           0         0.00
# 4161 2024-09-30      S02  SKU001       10.49           1         0.19
# 4163 2024-09-30      S02  SKU002       15.49           0         0.00
# 4165 2024-09-30      S02  SKU003       21.99           0         0.00
# 4167 2024-09-30      S03  SKU001       10.49           0         0.00
# 4169 2024-09-30      S03  SKU002       15.49           0         0.00
# 4171 2024-09-30      S03  SKU003       21.99           0         0.00
# 4173 2024-09-30      S04  SKU001       10.49           0         0.00
# 4175 2024-09-30      S04  SKU002       15.49           0         0.00
# 4177 2024-09-30      S04  SKU003       21.99           0         0.00
# 4179 2024-09-30      S05  SKU001       10.49           1         0.20
# 4181 2024-09-30      S05  SKU002       15.49           0         0.00
# 4183 2024-09-30      S05  SKU003       21.99           0         0.00
#
#       final_price  competitor_price  holiday_flag  weather_index  \
# 4155        10.49              9.57             0          0.207
# 4157        15.49             14.61             0          0.207
# 4159        21.99             20.91             0          0.207
# 4161         8.50             10.20             0          0.207
# 4163        15.49             15.04             0          0.207
# 4165        21.99             18.85             0          0.207
# 4167        10.49              9.92             0          0.207
# 4169        15.49             14.41             0          0.207
# 4171        21.99             20.64             0          0.207
# 4173        10.49              9.52             0          0.207
# 4175        15.49             14.65             0          0.207
# 4177        21.99             20.72             0          0.207
# 4179         8.39              9.81             0          0.207
# 4181        15.49             14.92             0          0.207
# 4183        21.99             20.41             0          0.207
#
#       week_of_year  units_sold  revenue  margin  stock_cap  stockout_flag  \
# 4155            39          13   136.37   81.77         26              0
# 4157            39          17   263.33  149.43         48              0
# 4159            39          17   373.83  212.33         47              0
# 4161            39          25   212.50  107.50         29              0
# 4163            39          25   387.25  219.75         50              0
# 4165            39          12   263.88  149.88         68              0
# 4167            39          38   398.62  239.02        104              0
# 4169            39          24   371.76  210.96         59              0
# 4171            39          27   593.73  337.23         45              0
# 4173            39          36   377.64  226.44         39              0
# 4175            39          33   511.17  290.07        100              0
# 4177            39          19   417.81  237.31         41              0
# 4179            39          62   520.18  259.78         78              0
# 4181            39          28   433.72  246.12         28              1
# 4183            39          19   417.81  237.31         86              0
#
#         set
# 4155  train
# 4157  train
# 4159  train
# 4161  train
# 4163  train
# 4165  train
# 4167  train
# 4169  train
# 4171  train
# 4173  train
# 4175  train
# 4177  train
# 4179  train
# 4181  train
# 4183  train

# %%
df0[(df0.date>=datetime.datetime(2024,2,1))&(df0.date<=datetime.datetime(2024,9,30))]
# Out:
#            date store_id  sku_id  base_price  promo_flag  promo_depth  \
# 465  2024-02-01      S01  SKU001       10.49           0         0.00
# 466  2024-02-01      S01  SKU002       15.49           0         0.00
# 467  2024-02-01      S01  SKU003       21.99           1         0.06
# 468  2024-02-01      S02  SKU001       10.49           1         0.13
# 469  2024-02-01      S02  SKU002       15.49           0         0.00
# ...         ...      ...     ...         ...         ...          ...
# 4180 2024-09-30      S05  SKU001       10.49           1         0.20
# 4181 2024-09-30      S05  SKU002       15.49           0         0.00
# 4182 2024-09-30      S05  SKU002       15.49           0         0.00
# 4183 2024-09-30      S05  SKU003       21.99           0         0.00
# 4184 2024-09-30      S05  SKU003       21.99           0         0.00
#
#       final_price  competitor_price  holiday_flag  weather_index  ...  \
# 465         10.49             10.83             0          0.637  ...
# 466         15.49             15.92             0          0.637  ...
# 467         20.67             22.66             0          0.637  ...
# 468          9.13             11.04             0          0.637  ...
# 469         15.49             15.58             0          0.637  ...
# ...           ...               ...           ...            ...  ...
# 4180         8.39              9.81             0          0.207  ...
# 4181        15.49             14.92             0          0.207  ...
# 4182        15.49             14.92             0          0.207  ...
# 4183        21.99             20.41             0          0.207  ...
# 4184        21.99             20.41             0          0.207  ...
#
#       onehot_july  onehot_august  onehot_september  onehot_october  \
# 465             0              0                 0               0
# 466             0              0                 0               0
# 467             0              0                 0               0
# 468             0              0                 0               0
# 469             0              0                 0               0
# ...           ...            ...               ...             ...
# 4180            0              0                 1               0
# 4181            0              0                 1               0
# 4182            0              0                 1               0
# 4183            0              0                 1               0
# 4184            0              0                 1               0
#
#       onehot_november  onehot_december onehot_spring onehot_summer  \
# 465                 0                0             0             0
# 466                 0                0             0             0
# 467                 0                0             0             0
# 468                 0                0             0             0
# 469                 0                0             0             0
# ...               ...              ...           ...           ...
# 4180                0                0             0             0
# 4181                0                0             0             0
# 4182                0                0             0             0
# 4183                0                0             0             0
# 4184                0                0             0             0
#
#      onehot_autumn onehot_winter
# 465              0             1
# 466              0             1
# 467              0             1
# 468              0             1
# 469              0             1
# ...            ...           ...
# 4180             1             0
# 4181             1             0
# 4182             1             0
# 4183             1             0
# 4184             1             0
#
# [3720 rows x 48 columns]

# %%
df0.holiday_flag.mean()
# Out:
# np.float64(0.021505376344086023)

# %%
df0.columns
# Out:
# Index(['date', 'store_id', 'sku_id', 'base_price', 'promo_flag', 'promo_depth',
#        'final_price', 'competitor_price', 'holiday_flag', 'weather_index',
#        'week_of_year', 'units_sold', 'revenue', 'margin', 'stock_cap',
#        'stockout_flag', 'set', 'day_of_week', 'month_of_year', 'season',
#        'sold_yesterday', 'sold_last_week', 'sold_last_month', 'final_price_ln',
#        'competitor_price_diff', 'onehot_monday', 'onehot_tuesday',
#        'onehot_wednesday', 'onehot_thursday', 'onehot_friday',
#        'onehot_saturday', 'onehot_sunday', 'onehot_january', 'onehot_february',
#        'onehot_march', 'onehot_april', 'onehot_may', 'onehot_june',
#        'onehot_july', 'onehot_august', 'onehot_september', 'onehot_october',
#        'onehot_november', 'onehot_december', 'onehot_spring', 'onehot_summer',
#        'onehot_autumn', 'onehot_winter'],
#       dtype='object')

# %%
numeric_cols = ['base_price', 'promo_flag', 'promo_depth',
       'final_price', 'competitor_price', 'holiday_flag', 'weather_index',
       'week_of_year', 'units_sold', 'revenue', 'margin', 'stock_cap',
       'stockout_flag', 'sold_yesterday', 'sold_last_week', 'sold_last_month', 'final_price_ln',
       'competitor_price_diff', 'onehot_monday', 'onehot_tuesday',
       'onehot_wednesday', 'onehot_thursday', 'onehot_friday',
       'onehot_saturday', 'onehot_sunday', 'onehot_january', 'onehot_february',
       'onehot_march', 'onehot_april', 'onehot_may', 'onehot_june',
       'onehot_july', 'onehot_august', 'onehot_september', 'onehot_october',
       'onehot_november', 'onehot_december', 'onehot_spring', 'onehot_summer',
       'onehot_autumn', 'onehot_winter']
category_cols = ['store_id', 'sku_id', 'day_of_week', 'month_of_year', 'season']

# %%
df0[['date', 'store_id', 'sku_id', 'base_price', 'promo_flag', 'promo_depth',
       'final_price', 'competitor_price', 'holiday_flag', 'weather_index',
       'week_of_year', 'units_sold', 'revenue', 'margin', 'stock_cap',
       'stockout_flag', 'set', 'sold_yesterday', 'sold_last_week',
       'sold_last_month', 'day_of_week', 'month_of_year', 'season',
       'final_price_ln', 'competitor_price_diff']].head()
# Out:
#         date store_id  sku_id  base_price  promo_flag  promo_depth  \
# 0 2024-01-01      S01  SKU001       10.49           0          0.0
# 1 2024-01-01      S01  SKU002       15.49           0          0.0
# 2 2024-01-01      S01  SKU003       21.99           0          0.0
# 3 2024-01-01      S02  SKU001       10.49           1          0.1
# 4 2024-01-01      S02  SKU002       15.49           0          0.0
#
#    final_price  competitor_price  holiday_flag  weather_index  ...  \
# 0        10.49             10.02             1          0.291  ...
# 1        15.49             15.04             1          0.291  ...
# 2        21.99             21.20             1          0.291  ...
# 3         9.44             10.30             1          0.291  ...
# 4        15.49             16.45             1          0.291  ...
#
#    stockout_flag    set  sold_yesterday  sold_last_week  sold_last_month  \
# 0              0  train              -1              -1               -1
# 1              0  train              -1              -1               -1
# 2              0  train              -1              -1               -1
# 3              0  train              -1              -1               -1
# 4              0  train              -1              -1               -1
#
#    day_of_week month_of_year  season  final_price_ln  competitor_price_diff
# 0       monday       january  winter        2.350422              -0.044805
# 1       monday       january  winter        2.740195              -0.029051
# 2       monday       january  winter        3.090588              -0.035925
# 3       monday       january  winter        2.244956               0.091102
# 4       monday       january  winter        2.740195               0.061975
#
# [5 rows x 25 columns]

# %%
df0[df0.set == 'train']['date'].max()
# Out:
# Timestamp('2024-09-30 00:00:00')

# %%
df0[df0.set == 'test']['date'].min()
# Out:
# Timestamp('2024-10-01 00:00:00')

# %% [markdown]
# # EDA
# - Identify main demand drivers (price, promo, holiday, weather, weekly/annual patterns, store effects).
# - Check price elasticity by SKU and promo effect sizes.
# - Detect stockouts and discuss their impact on demand estimation.

# %% [markdown]
# ## Quick check datastats

# %%
df = df0[df0.stockout_flag == 0].reset_index(drop = True).copy()

# %%
df.groupby(['store_id','sku_id'])['units_sold'].count()
# Out:
# store_id  sku_id
# S01       SKU001    360
#           SKU002    361
#           SKU003    354
# S02       SKU001    347
#           SKU002    342
#           SKU003    342
# S03       SKU001    335
#           SKU002    329
#           SKU003    338
# S04       SKU001    316
#           SKU002    305
#           SKU003    316
# S05       SKU001    290
#           SKU002    301
#           SKU003    304
# Name: units_sold, dtype: Int64

# %%
df.groupby(['store_id','sku_id'])['units_sold'].mean()
# Out:
# store_id  sku_id
# S01       SKU001    17.866667
#           SKU002    18.684211
#           SKU003    16.177966
# S02       SKU001    21.414986
#           SKU002    22.608187
#           SKU003    20.087719
# S03       SKU001    26.235821
#           SKU002    26.790274
#           SKU003    23.275148
# S04       SKU001    31.037975
#           SKU002    31.465574
#           SKU003    27.117089
# S05       SKU001    34.475862
#           SKU002     35.10299
#           SKU003    31.776316
# Name: units_sold, dtype: Float64

# %%
df.groupby(['store_id','sku_id'])['base_price'].mean()
# Out:
# store_id  sku_id
# S01       SKU001    10.49
#           SKU002    15.49
#           SKU003    21.99
# S02       SKU001    10.49
#           SKU002    15.49
#           SKU003    21.99
# S03       SKU001    10.49
#           SKU002    15.49
#           SKU003    21.99
# S04       SKU001    10.49
#           SKU002    15.49
#           SKU003    21.99
# S05       SKU001    10.49
#           SKU002    15.49
#           SKU003    21.99
# Name: base_price, dtype: float64

# %% [markdown]
# - Sales Store 5 > Store 4 > Store 3 > Store 2 > Store 1
# - Need to distinguish 5 stores in the analysis and modeling

# %%
stores = list(df['store_id'].unique())
skus = list(df['sku_id'].unique())

# %%
stores
# Out:
# ['S01', 'S02', 'S03', 'S04', 'S05']

# %%
skus
# Out:
# ['SKU001', 'SKU002', 'SKU003']

# %% [markdown]
# ### Price ~ Demand
# There is a negative relationship

# %%
for sk in skus:
    for st in stores:
        df_price = df[(df.store_id == st) & (df.sku_id == sk)]
        min_price = df_price['final_price'].min()
        max_price = df_price['final_price'].max()
        if df_price.empty: 
            pass
        else:
            avg = df_price.groupby(pd.cut(df_price["final_price"], bins=6))["units_sold"].mean()
            plt.figure(figsize=(4,3))
            avg.plot(kind="bar")
            plt.title(f"Store {st} - {sk}", fontsize=8)
            plt.xlabel("Price bin", fontsize=7)
            plt.ylabel("Avg Demand", fontsize=7)
            plt.xticks(fontsize=6)
            plt.yticks(fontsize=6)
            plt.tight_layout()
            plt.show()

# %% [markdown]
# ### Promo ~ Demand
# Overall, bigger promotion percentage does drive bigger sales, same effect on all skus and stores

# %%
for sk in skus:
    for st in stores:
        df_price = df[(df.store_id == st) & (df.sku_id == sk)]
        if df_price.empty: 
            pass
        else:
            avg = df_price.groupby(pd.cut(df_price["promo_depth"], bins=5))["units_sold"].mean()
            plt.figure(figsize=(4,3)); avg.plot(kind="bar")
            plt.title(f"Store {st} - {sk}", fontsize=8)
            plt.xlabel("Promo bin", fontsize=7)
            plt.ylabel("Avg Demand", fontsize=7)
            plt.xticks(fontsize=6)
            plt.yticks(fontsize=6)
            plt.tight_layout()
            plt.show()

# %% [markdown]
# ### Holiday ~ Demand
# Sometimes non-holiday days sell more, could be because of promotion

# %%
for sk in skus:
    for st in stores:
        df_price = df[(df.store_id == st) & (df.sku_id == sk)]
        if df_price.empty: 
            pass
        else:
            keys = sorted(df_price["holiday_flag"].dropna().unique())
            data = [df_price.loc[df_price["holiday_flag"]==k, "units_sold"].values for k in keys]
            plt.figure(figsize=(4,3))
            plt.boxplot(data, widths=0.7, labels=[str(int(k)) for k in keys], showmeans=True, whis=[0,100])
            plt.title(f"Store {st} - {sk}", fontsize=8)
            plt.xlabel("Holiday Flag", fontsize=7)
            plt.ylabel("Units Sold", fontsize=7)
            plt.xticks(fontsize=6)
            plt.yticks(fontsize=6)
            plt.tight_layout()
            plt.show()

# %% [markdown]
# ### Weather ~ Demand

# %%
for st in stores:
    for sk in skus:
        df_price = df[(df.store_id == st) & (df.sku_id == sk)]
        if df_price.empty: 
            pass
        else:
            plt.figure(figsize=(4,3))
            plt.scatter(x=df_price.weather_index, y=df_price.units_sold, alpha = 0.5)
            plt.title(f"Store {st} - {sk}", fontsize=8)
            plt.xlabel("Weather", fontsize=7)
            plt.ylabel("Units Sold", fontsize=7)
            plt.xticks(fontsize=6)
            plt.yticks(fontsize=6)
            plt.tight_layout()
            plt.show()

# %% [markdown]
# ### Annual patterns ~ Demand

# %%
for sk in skus:
    for st in stores:
        df_price = df[(df.store_id == st) & (df.sku_id == sk)]
        if df_price.empty: 
            pass
        else:
            avg = df_price.groupby('month_of_year')["units_sold"].sum()
            plt.figure(figsize=(4,3))
            avg.plot(kind="line")
            plt.title(f"Store {st} - {sk}", fontsize=8)
            plt.xlabel("Months", fontsize=7)
            plt.ylabel("Units Sold", fontsize=7)
            plt.xticks(fontsize=6)
            plt.yticks(fontsize=6)
            plt.tight_layout()
            plt.show()

# %% [markdown]
# ### Weekly patterns ~ Demand

# %%
for sk in skus:
    for st in stores:
        df_price = df[(df.store_id == st) & (df.sku_id == sk)]
        if df_price.empty: 
            pass
        else:
            avg = df_price.groupby('day_of_week')["units_sold"].mean()
            plt.figure(figsize=(4,3))
            avg.plot(kind="line")
            plt.title(f"Store {st} - {sk}", fontsize=8)
            plt.xlabel("Week Day", fontsize=7)
            plt.ylabel("Units Sold", fontsize=7)
            plt.xticks(fontsize=6)
            plt.yticks(fontsize=6)
            plt.tight_layout()
            plt.show()

# %% [markdown]
# ## Price Elasticity
# price elasticity by SKU and promo effect sizes

# %%
for sk in skus:
    print(f'Check {sk} price sensitivity:')

    d = df[(df.sku_id == sk)].reset_index(drop = True).copy()
    d["ln_units"] = np.log(d["units_sold"])
    
    # calendar controls you kept (already removed Sunday/December)
    calendar = [
        'onehot_monday','onehot_tuesday','onehot_wednesday','onehot_thursday','onehot_friday','onehot_saturday',
        'onehot_january','onehot_february','onehot_march','onehot_april','onehot_may','onehot_june',
        'onehot_july','onehot_august','onehot_september','onehot_october','onehot_november'
    ]
    # keep only those that exist
    calendar = [c for c in calendar if c in d.columns]
    
    # feature matrix
    cols = ["final_price_ln", "promo_flag", "holiday_flag", "competitor_price_diff",] + calendar
    X = d[cols].values
    y = d["ln_units"].values
    
    # fit OLS via scikit-learn
    model = LinearRegression(fit_intercept=True).fit(X, y)
    coef = dict(zip(cols, model.coef_))
    
    # effects
    price_elast   = coef["final_price_ln"]
    promo_effect_size   = (np.exp(coef["promo_flag"]) - 1) * 100            # % lift when promo_flag=1
    
    print(f"Price elasticity: {price_elast:.3f}")
    print(f"Promo effect size (%): {promo_effect_size:.2f} \n")
    print(coef, '\n')
    # break
# Out:
# Check SKU001 price sensitivity:
# Price elasticity: -0.290
# Promo effect size (%): 27.04
#
# {'final_price_ln': np.float64(-0.290206514023591), 'promo_flag': np.float64(0.23931909743903584), 'holiday_flag': np.float64(0.20276823360538876), 'competitor_price_diff': np.float64(0.9795791335210183), 'onehot_monday': np.float64(-0.14542015632311345), 'onehot_tuesday': np.float64(-0.1540515203968145), 'onehot_wednesday': np.float64(-0.15141221605303049), 'onehot_thursday': np.float64(-0.14934246511579374), 'onehot_friday': np.float64(-0.16067415536420113), 'onehot_saturday': np.float64(0.01925441480791988), 'onehot_january': np.float64(-0.30305583906227207), 'onehot_february': np.float64(-0.22334348837388596), 'onehot_march': np.float64(-0.014389162809847433), 'onehot_april': np.float64(0.18910357599021682), 'onehot_may': np.float64(0.38967108229814673), 'onehot_june': np.float64(0.6004685740381449), 'onehot_july': np.float64(0.6661800575634176), 'onehot_august': np.float64(0.6015391576524145), 'onehot_september': np.float64(0.4421829155671409), 'onehot_october': np.float64(0.2805682508954581), 'onehot_november': np.float64(0.09380477017902335)}
#
# Check SKU002 price sensitivity:
# Price elasticity: -0.591
# Promo effect size (%): 39.99
#
# {'final_price_ln': np.float64(-0.5912178383289719), 'promo_flag': np.float64(0.3364153013772158), 'holiday_flag': np.float64(0.1983785984315504), 'competitor_price_diff': np.float64(0.6664726385287781), 'onehot_monday': np.float64(-0.14684320289001546), 'onehot_tuesday': np.float64(-0.1317304176538713), 'onehot_wednesday': np.float64(-0.17036384743282065), 'onehot_thursday': np.float64(-0.17761574211207903), 'onehot_friday': np.float64(-0.1288842776116115), 'onehot_saturday': np.float64(0.051542885131020615), 'onehot_january': np.float64(-0.3244252915232963), 'onehot_february': np.float64(-0.4322406800552716), 'onehot_march': np.float64(-0.5322638259393707), 'onehot_april': np.float64(-0.6006793716031812), 'onehot_may': np.float64(-0.6456944579502786), 'onehot_june': np.float64(-0.6316987667716645), 'onehot_july': np.float64(-0.5020867507366829), 'onehot_august': np.float64(-0.3667310867929402), 'onehot_september': np.float64(-0.25136541487863273), 'onehot_october': np.float64(-0.09577877957458227), 'onehot_november': np.float64(-0.06519840875589061)}
#
# Check SKU003 price sensitivity:
# Price elasticity: -1.574
# Promo effect size (%): 47.27
#
# {'final_price_ln': np.float64(-1.5738451552301458), 'promo_flag': np.float64(0.3870828923367277), 'holiday_flag': np.float64(0.2540406015189051), 'competitor_price_diff': np.float64(0.42469395740385313), 'onehot_monday': np.float64(-0.19372058653517063), 'onehot_tuesday': np.float64(-0.23481742024659497), 'onehot_wednesday': np.float64(-0.19079783132124645), 'onehot_thursday': np.float64(-0.22268553040675937), 'onehot_friday': np.float64(-0.1728764789073241), 'onehot_saturday': np.float64(-0.03243847278086149), 'onehot_january': np.float64(-0.13996301425759586), 'onehot_february': np.float64(-0.07134253317370849), 'onehot_march': np.float64(0.03466022135259105), 'onehot_april': np.float64(0.21340349275855336), 'onehot_may': np.float64(0.2684896780008223), 'onehot_june': np.float64(0.3076731086589816), 'onehot_july': np.float64(0.3093094155939618), 'onehot_august': np.float64(0.20244419563800642), 'onehot_september': np.float64(0.11188750117760345), 'onehot_october': np.float64(0.10102281818156449), 'onehot_november': np.float64(-0.012138442062973806)}

# %% [markdown]
# - Price sensitivity: SKU003 > SKU002 > SKU001
# - SKU001 is insensitive to price change, but its demand is heavily affected by seasons, especially high coefficient in the summer months

# %% [markdown]
# # Baseline forecasting model

# %%
df.columns
# Out:
# Index(['date', 'store_id', 'sku_id', 'base_price', 'promo_flag', 'promo_depth',
#        'final_price', 'competitor_price', 'holiday_flag', 'weather_index',
#        'week_of_year', 'units_sold', 'revenue', 'margin', 'stock_cap',
#        'stockout_flag', 'set', 'day_of_week', 'month_of_year', 'season',
#        'sold_yesterday', 'sold_last_week', 'sold_last_month', 'final_price_ln',
#        'competitor_price_diff', 'onehot_monday', 'onehot_tuesday',
#        'onehot_wednesday', 'onehot_thursday', 'onehot_friday',
#        'onehot_saturday', 'onehot_sunday', 'onehot_january', 'onehot_february',
#        'onehot_march', 'onehot_april', 'onehot_may', 'onehot_june',
#        'onehot_july', 'onehot_august', 'onehot_september', 'onehot_october',
#        'onehot_november', 'onehot_december', 'onehot_spring', 'onehot_summer',
#        'onehot_autumn', 'onehot_winter'],
#       dtype='object')

# %%
feature_cols = ['store_id', 'sku_id', 'base_price', 'promo_flag', 'promo_depth',
       'final_price', 'competitor_price', 'holiday_flag', 'weather_index',
       'day_of_week', 'month_of_year', 'season',
       'sold_yesterday', 'sold_last_week', 'sold_last_month', 'final_price_ln',
       'competitor_price_diff']
target_col = 'units_sold'
split_col = 'set'

# %%
X_train = df[df[split_col] == 'train'][feature_cols]
y_train = df[df[split_col] == 'train'][target_col]
X_test = df[df[split_col] == 'test'][feature_cols]
y_test = df[df[split_col] == 'test'][target_col]

# %%
modeling.fit(X_train, y_train)
# Out:
# [0]	validation_0-rmse:11.82196
# [1]	validation_0-rmse:11.45243
# [2]	validation_0-rmse:11.08443
# [3]	validation_0-rmse:10.79947
# [4]	validation_0-rmse:10.55250
# [5]	validation_0-rmse:10.28648
# [6]	validation_0-rmse:10.02420
# [7]	validation_0-rmse:9.78316
# [8]	validation_0-rmse:9.59372
# [9]	validation_0-rmse:9.39646
# [10]	validation_0-rmse:9.22025
# [11]	validation_0-rmse:9.05225
# [12]	validation_0-rmse:8.88150
# [13]	validation_0-rmse:8.71810
# [14]	validation_0-rmse:8.54971
# [15]	validation_0-rmse:8.40860
# [16]	validation_0-rmse:8.26556
# [17]	validation_0-rmse:8.17024
# [18]	validation_0-rmse:8.05228
# [19]	validation_0-rmse:7.94291
# [20]	validation_0-rmse:7.85233
# [21]	validation_0-rmse:7.74213
# [22]	validation_0-rmse:7.64252
# [23]	validation_0-rmse:7.55728
# [24]	validation_0-rmse:7.47686
# [25]	validation_0-rmse:7.39247
# [26]	validation_0-rmse:7.31397
# [27]	validation_0-rmse:7.23644
# [28]	validation_0-rmse:7.17553
# [29]	validation_0-rmse:7.11300
# [30]	validation_0-rmse:7.05719
# [31]	validation_0-rmse:7.02358
# [32]	validation_0-rmse:6.98266
# [33]	validation_0-rmse:6.94871
# [34]	validation_0-rmse:6.89834
# [35]	validation_0-rmse:6.86540
# [36]	validation_0-rmse:6.82143
# [37]	validation_0-rmse:6.77258
# [38]	validation_0-rmse:6.72860
# [39]	validation_0-rmse:6.69219
# [40]	validation_0-rmse:6.65759
# [41]	validation_0-rmse:6.63155
# [42]	validation_0-rmse:6.60772
# [43]	validation_0-rmse:6.58109
# [44]	validation_0-rmse:6.56267
# [45]	validation_0-rmse:6.53833
# [46]	validation_0-rmse:6.51476
# [47]	validation_0-rmse:6.49130
# [48]	validation_0-rmse:6.46797
# [49]	validation_0-rmse:6.43828
# [50]	validation_0-rmse:6.42369
# [51]	validation_0-rmse:6.40055
# [52]	validation_0-rmse:6.38023
# [53]	validation_0-rmse:6.36585
# [54]	validation_0-rmse:6.35154
# [55]	validation_0-rmse:6.32787
# [56]	validation_0-rmse:6.31583
# [57]	validation_0-rmse:6.30372
# [58]	validation_0-rmse:6.28687
# [59]	validation_0-rmse:6.27866
# [60]	validation_0-rmse:6.26117
# [61]	validation_0-rmse:6.24998
# [62]	validation_0-rmse:6.23727
# [63]	validation_0-rmse:6.22702
# [64]	validation_0-rmse:6.21547
# [65]	validation_0-rmse:6.20596
# [66]	validation_0-rmse:6.18757
# [67]	validation_0-rmse:6.17830
# [68]	validation_0-rmse:6.17321
# [69]	validation_0-rmse:6.16455
# [70]	validation_0-rmse:6.14579
# [71]	validation_0-rmse:6.13253
# [72]	validation_0-rmse:6.12281
# [472]	validation_0-rmse:5.74389
# [473]	validation_0-rmse:5.74368
# [474]	validation_0-rmse:5.74330
# [475]	validation_0-rmse:5.74370
# [476]	validation_0-rmse:5.74383
# [477]	validation_0-rmse:5.74278
# [478]	validation_0-rmse:5.74072
# [479]	validation_0-rmse:5.74090
# [480]	validation_0-rmse:5.74130
# [481]	validation_0-rmse:5.74152
# [482]	validation_0-rmse:5.74283
# [483]	validation_0-rmse:5.74392
# [484]	validation_0-rmse:5.74470
# [485]	validation_0-rmse:5.74452
# [486]	validation_0-rmse:5.74512
# [487]	validation_0-rmse:5.74451
# [488]	validation_0-rmse:5.74610
# [489]	validation_0-rmse:5.74516
# [490]	validation_0-rmse:5.74377
# [491]	validation_0-rmse:5.74269
# [492]	validation_0-rmse:5.74124
# [493]	validation_0-rmse:5.74126
# [494]	validation_0-rmse:5.74108
# [495]	validation_0-rmse:5.74114
# [496]	validation_0-rmse:5.74163
# [497]	validation_0-rmse:5.74099
# [498]	validation_0-rmse:5.74162
# [499]	validation_0-rmse:5.74059
# 'forecaster_xgboost_20250909_133118.pkl'

# %%
modeling.validate('forecaster_xgboost_20250909_115145.pkl', X_train, y_train)
# Out:
# Validation metrics for forecaster_xgboost_20250909_115145.pkl:
#   R^2  : 0.9239
#   RMSE : 3.422126
#   MAPE : 12.27%
# {'r2': 0.9239038825035095,
#  'rmse': 3.4221258202168037,
#  'mape_pct': 12.268572952109297}

# %%
modeling.validate('forecaster_xgboost_20250909_115145.pkl', X_test, y_test)
# Out:
# Validation metrics for forecaster_xgboost_20250909_115145.pkl:
#   R^2  : 0.6354
#   RMSE : 8.103878
#   MAPE : 26.20%
# {'r2': 0.6354064345359802,
#  'rmse': 8.1038783266474,
#  'mape_pct': 26.195415029938275}

# %% [markdown]
# - There is a clear overfitting sight due to unable to model the seasonality

# %%
modeling.validate('forecaster_xgboost_20250909_115145.pkl', df[(df[split_col] == 'test') & (df.sku_id == 'SKU001')][feature_cols], df[(df[split_col] == 'test') & (df.sku_id == 'SKU001')][target_col])
# Out:
# Validation metrics for forecaster_xgboost_20250909_115145.pkl:
#   R^2  : 0.5339
#   RMSE : 6.826361
#   MAPE : 28.07%
# {'r2': 0.5338824391365051,
#  'rmse': 6.826361037704484,
#  'mape_pct': 28.065261348578435}

# %%
modeling.validate('forecaster_xgboost_20250909_115145.pkl', df[(df[split_col] == 'test') & (df.sku_id == 'SKU002')][feature_cols], df[(df[split_col] == 'test') & (df.sku_id == 'SKU002')][target_col])
# Out:
# Validation metrics for forecaster_xgboost_20250909_115145.pkl:
#   R^2  : 0.3358
#   RMSE : 11.290900
#   MAPE : 24.42%
# {'r2': 0.3358404040336609,
#  'rmse': 11.290900247799629,
#  'mape_pct': 24.42044280047621}

# %%
modeling.validate('forecaster_xgboost_20250909_115145.pkl', df[(df[split_col] == 'test') & (df.sku_id == 'SKU003')][feature_cols], df[(df[split_col] == 'test') & (df.sku_id == 'SKU003')][target_col])
# Out:
# Validation metrics for forecaster_xgboost_20250909_115145.pkl:
#   R^2  : 0.8122
#   RMSE : 5.662609
#   MAPE : 25.81%
# {'r2': 0.812159538269043,
#  'rmse': 5.662609255917724,
#  'mape_pct': 25.810359880441375}

# %% [markdown]
# - As we conclude above,

# %% [markdown]
# # Optimizer
# Maximize revenue subject to price bounds & promo constraints

# %%
price_plan = optimize_price_plan('submission/src/models/forecaster_xgboost_20250909_115145.pkl', '2024-03-01', 30)
price_plan
# Out:
# === Optimization Summary ===
# Horizon days         : 30
# Date range           : 2024-03-01 → 2024-03-30
# Total baseline rev   : 81,631.01
# Total optimized rev  : 96,457.71
# Revenue lift         : 14,826.70 (18.16%)
# Exported price plan to C:\Users\thi.n\Documents\Projects\simcel\submission\src\pricing\price_plan_20240301_30days_20250909_151434.csv
#            date store_id  sku_id  final_price  promo_depth  pred_units  \
# 0    2024-03-01      S01  SKU001    10.490000     0.000000   10.335397
# 1    2024-03-01      S01  SKU002    15.490000     0.000000   11.570021
# 2    2024-03-01      S01  SKU003    21.990000     0.000000   12.013826
# 3    2024-03-01      S02  SKU001    10.490000     0.000000   10.335397
# 4    2024-03-01      S02  SKU002    15.490000     0.000000   11.570021
# ..          ...      ...     ...          ...          ...         ...
# 445  2024-03-30      S04  SKU002    13.424667     0.133333   29.228258
# 446  2024-03-30      S04  SKU003    19.058000     0.133333   30.801310
# 447  2024-03-30      S05  SKU001     9.091333     0.133333   24.353130
# 448  2024-03-30      S05  SKU002    13.424667     0.133333   29.228258
# 449  2024-03-30      S05  SKU003    19.058000     0.133333   30.801310
#
#         revenue  is_promo  baseline_price  baseline_units  baseline_revenue  \
# 0    108.418312         0           10.49       10.335397        108.418312
# 1    179.219620         0           15.49       11.570021        179.219620
# 2    264.184042         0           21.99       12.013826        264.184042
# 3    108.418312         0           10.49       10.335397        108.418312
# 4    179.219620         0           15.49       11.570021        179.219620
# ..          ...       ...             ...             ...               ...
# 445  392.379623         1           15.49       12.726660        197.135960
# 446  587.011358         1           21.99       13.339355        293.332427
# 447  221.402426         1           10.49       11.177971        117.256915
# 448  392.379623         1           15.49       12.726660        197.135960
# 449  587.011358         1           21.99       13.339355        293.332427
#
#      uplift_revenue
# 0          0.000000
# 1          0.000000
# 2          0.000000
# 3          0.000000
# 4          0.000000
# ..              ...
# 445      195.243663
# 446      293.678931
# 447      104.145511
# 448      195.243663
# 449      293.678931
#
# [450 rows x 12 columns]

# %%
# Manually calculate the revenue from the ground truth file
df0[(df0.date>=datetime.datetime(2024,3,1)) & (df0.date<=datetime.datetime(2024,3,30))]['revenue'].sum()
# Out:
# np.float64(154945.88999999998)

# %%
# Manually calculate the revenue from the ground truth file
df0[(df0.date>=datetime.datetime(2024,3,1)) & (df0.date<=datetime.datetime(2024,3,30))]\
    .groupby(['sku_id'])['promo_flag'].sum()

# different assumptions
# Out:
# sku_id
# SKU001    30
# SKU002    18
# SKU003    34
# Name: promo_flag, dtype: Int64

# %% [markdown]
# # Pricing impact simulation pipeline
